# %% [markdown]
# <a href="https://colab.research.google.com/github/Joeaviator/TWO_POINT_CLASSIFICATION/blob/main/TWO_POINT_CLASSIFCIATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import seaborn as sns
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-c1c957fd-c682-4ef9-b88f-3f8fb3eb1d32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1c957fd-c682-4ef9-b88f-3f8fb3eb1d32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.isnull()
# Out:
#       age  bought_insurance
# 0   False             False
# 1   False             False
# 2   False             False
# 3   False             False
# 4   False             False
# 5   False             False
# 6   False             False
# 7   False             False
# 8   False             False
# 9   False             False
# 10  False             False
# 11  False             False
# 12  False             False
# 13  False             False
# 14  False             False
# 15  False             False
# 16  False             False
# 17  False             False
# 18  False             False
# 19  False             False
# 20  False             False
# 21  False             False
# 22  False             False
# 23  False             False
# 24  False             False
# 25  False             False
# 26  False             False

# %%
sns.boxplot(df["age"])
# Out:
# <Axes: ylabel='age'>

# %%
x=df.drop(columns="bought_insurance",axis=1)
y=df["bought_insurance"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions=model.predict(x_test)

# %%
accuracy_score(predictions,y_test)
# Out:
# 1.0

# %%
ds=pd.DataFrame({"Actual Values":y_test, "Predicted Values":predictions})
ds.head(10)
# Out:
#     Actual Values  Predicted Values
# 1               0                 0
# 7               1                 1
# 20              0                 0
# 4               1                 1
# 21              0                 0
# 26              0                 0

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
x=df.drop(columns="age",axis=1)
y=df["age"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict=model.predict(x_test)

# %%
r2 = r2_score(y_test,predict)
r2
# Out:
# 0.4387330241016614

# %%
de=pd.DataFrame({"Actual Values":y_test, "Predicted Values": predict})
de.head()
# Out:
#     Actual Values  Predicted Values
# 12             27         28.181818
# 8              62         51.200000
# 16             25         51.200000
# 21             26         28.181818
# 25             54         51.200000
